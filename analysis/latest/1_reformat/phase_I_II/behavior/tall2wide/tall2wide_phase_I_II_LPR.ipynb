# %%
##### overall explanation
# 1. reformat LPR data to have t0-t239
# 2. reformat EPR data to have t1-t49

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, time

import warnings
warnings.filterwarnings('ignore')

# %%
starting_dir = os.getcwd()
print (starting_dir)
# Out:
# /Users/kimd999/research/script_not_in_dropbox/srpAnalytics/analysis/latest/1_reformat/phase_I_II/behavior

# %% [markdown]
# ### Reformat LPR behavioral data

# %%
#mac
complete_input_file_path= '/Users/kimd999/research/projects/toxicity/per_each_data/Phase_I_II/input/behavioral/LPR/tall/344_zf_LPR_data_phase_1_2_2020JUNE25_updated_plate_id_for_TX_tall.csv'

#constance
#complete_input_file_path = '/people/kimd999/tox/phase_I_II/data/344_zf_LPR_data_phase_1_2_2020JUNE25_updated_plate_id_for_TX.csv'

behav_all_data = pd.read_csv(complete_input_file_path, header = 0)
#behav_all_data.head()

# %%
chemical_id_count = 0
for chemical_id in np.unique(behav_all_data['chemical.id']):
    chemical_id_count += 1
print ("chemical_id_count:"+str(chemical_id_count))
# Out:
# chemical_id_count:344

# %%
#len(behav_all_data)

# %%
#TX_bottle_id_behav_all_data = behav_all_data[behav_all_data['bottle.id'].str.contains("^TX")]
#TX_bottle_id_behav_all_data.head()

# %%
#len(TX_bottle_id_behav_all_data)

# %%
##### (start) replace plate.id in behavioral data with plate.id in morphological data (common data will be bottle.id)

#mac
#complete_morph_file_path = '/Users/kimd999/research/projects/toxicity/per_each_data/Phase_I_II/input/morphology/tall/zf_morphology_data_335_chemicals_2020DEC16.csv'

#constance
#complete_morph_file_path = '/people/kimd999/tox/phase_I_II_close_file_frequently/data/zf_morphology_data_335_chemicals_2020DEC16.csv'

#morph_all_data = pd.read_csv(complete_morph_file_path, header = 0)
#morph_all_data.head()

# %%
'''chemical_id_count = 0
for chemical_id in np.unique(morph_all_data['chemical.id']):
    chemical_id_count += 1
print ("chemical_id_count:"+str(chemical_id_count))
'''
# Out:
# 'chemical_id_count = 0\nfor chemical_id in np.unique(morph_all_data[\'chemical.id\']):\n    chemical_id_count += 1\nprint ("chemical_id_count:"+str(chemical_id_count))\n'

# %%
#len(morph_all_data)

# %%
#TX_bottle_id_morph_all_data = morph_all_data[morph_all_data['bottle.id'].str.contains("^TX")]
#TX_bottle_id_morph_all_data.head()

# %%
#len(TX_bottle_id_morph_all_data)

# %%
#new_behav_all_data = TX_bottle_id_behav_all_data.loc[TX_bottle_id_morph_all_data['bottle.id'],['chemical.id', 'bottle.id', 'conc', 'plate.id', 'well', 'endpoint', 'value']]

# %%
##### (end) replace plate.id in behavioral data with plate.id in morphological data (common data will be bottle.id)

# %%
#new_behav_all_data = behav_all_data.loc[behav_all_data['bottle.id'] == "TX002271",['chemical.id', 'bottle.id', 'conc', 'plate.id', 'well', 'endpoint', 'value']]

# %%
#new_behav_all_data.head()

# %%
# Keep only relevant columns
columns_to_keep = ['chemical.id', 'conc', 'plate.id', 'well', 'endpoint', 'value']
behav_all_data_select = behav_all_data.loc[:,columns_to_keep]
behav_all_data_select.head()
# Out:
#    chemical.id  conc     plate.id well endpoint  value
# 0         2752  0.64  TP972-H6-P1   B3       t3    0.4
# 1         2752  0.64  TP972-H6-P1   F3       t3    0.0
# 2         2752  6.40  TP972-H6-P1   B8       t3   37.5
# 3         2752  0.64  TP972-H6-P1   C3       t3    0.0
# 4         2752  0.64  TP972-H6-P1   F3       t3    0.0

# %%
display("chemical_id_count:"+str(len(np.unique(behav_all_data_select['chemical.id']))))
# Out:
# 'chemical_id_count:344'

# %%
#behav_all_data_select = behav_all_data_select.dropna(subset=['chemical.id'])
### no row is dropped

#display("chemical_id_count:"+str(len(np.unique(behav_all_data_select['chemical.id']))))
# Out:
# 'chemical_id_count:344'

# %%
#display(np.unique(behav_all_data['endpoint']))

# %%
#display(np.unique(behav_all_data_select['endpoint']))

# %%
#reformat_data.head()

# %%
#reformat_data.shape

# %%
#reformat_data.to_csv('Phase_I_II_t3_t17_LPR.csv',index=False)

# %%
###### replace plate id with what is listed in the morphology data to the LPR.
###### for your example, TP967-E9-P1, will go in place of plate.id “1” in the LPR file.

# read morpho data and match/join

# %% [markdown]
# ### t0_t239 time points

# %%
start_time = time.time()

reformatted_w_240_endpoints = pd.DataFrame()
reformatted_w_non_240_endpoints = pd.DataFrame()
    
len_group_endpoint = []
    
#full_devel = "full"
full_devel = "devel"

if (full_devel == "full"):
    # all chemicals
    chemical_id_from_here = np.unique(behav_all_data['chemical.id'])
else: # full_devel = "devel"
    #chemical_id_from_here = np.unique([53,54])
    #chemical_id_from_here = np.unique([155,163])
    #chemical_id_from_here = np.unique([155])
    chemical_id_from_here = np.unique([163])
    
for chemical_index in chemical_id_from_here:
    behav_data_chemical = behav_all_data_select.loc[behav_all_data['chemical.id'] == chemical_index,:]
    print("chemical_index:" + str(chemical_index))
    
    # Append chemical_plate_well as a unique identifier
    behav_data_chemical.insert(0, 'chemical_plate_well', behav_data_chemical.loc[:,['chemical.id','plate.id', 'well']].apply(lambda x: '_'.join(x.map(str)), axis = 1))
    
    #output_filename = str(chemical_index) + ".csv"
    #behav_data_chemical.to_csv(output_filename,index=False)
    
    for cpw in np.unique(behav_data_chemical.chemical_plate_well):
        per_cpw = behav_data_chemical.loc[behav_data_chemical.chemical_plate_well == cpw,:]

        per_cpw_grouped = per_cpw.groupby(['chemical.id', 'plate.id', 'well'])
        for name, group in per_cpw_grouped:
            
            #display("group.endpoint", group.endpoint.head())
            #len_group_endpoint.append(str(len(group.endpoint)))
            temp = pd.DataFrame(
                    {
                    'chemical.id': np.unique(per_cpw['chemical.id']),
                    'plate.id': np.unique(per_cpw['plate.id']),
                    'well': np.unique(per_cpw['well']),
                    'chemical_plate_well': np.unique(per_cpw['chemical_plate_well']),
                    'conc': np.unique(per_cpw['conc'])
                    })
            display("before concat:", temp.head())
            
            # Append additonal columns corresponding to time points
            for time_point in np.arange(len(group.endpoint)):
                end_point = 't'+ str(time_point)
                #print ("\nend_point:"+str(end_point))
                #print ("pd.DataFrame({end_point: per_cpw.value[per_cpw.endpoint == end_point]}):"\
                #   +str(pd.DataFrame({end_point: per_cpw.value[per_cpw.endpoint == end_point]})))
                #print ("pd.DataFrame({end_point: per_cpw.value[per_cpw.endpoint == end_point].values}):"\
                #   +str(pd.DataFrame({end_point: per_cpw.value[per_cpw.endpoint == end_point].values})))
                temp = pd.concat([temp, pd.DataFrame({end_point: per_cpw.value[per_cpw.endpoint == end_point].values})],axis = 1)
            display("after concat:", temp.head())


            if(len(group.endpoint) == 240): # because we are dealing t0-t239
                reformatted_w_240_endpoints = pd.concat([reformatted_w_240_endpoints, temp])
            else: # len(group.endpoint) != 240
                reformatted_w_non_240_endpoints = pd.concat([reformatted_w_non_240_endpoints, temp])
             

end_time = time.time()
time_took = str(round((end_time-start_time), 1)) + " seconds"
print ("Done, it took:"+str(time_took)) 
# took 2 minutes for 2 chemicals
# Out:
# chemical_index:163
# 'before concat:'
#    chemical.id     plate.id well chemical_plate_well  conc
# 0          163  TP967-E9-P1   A1  163_TP967-E9-P1_A1  64.0
# 'after concat:'
#    chemical.id     plate.id well chemical_plate_well  conc  t0  t1  t2   t3  \
# 0        163.0  TP967-E9-P1   A1  163_TP967-E9-P1_A1  64.0 NaN NaN NaN  0.0
# 1          NaN          NaN  NaN                 NaN   NaN NaN NaN NaN  0.9
#
#     t4  ...  t20  t21  t22  t23  t24  t25  t26  t27  t28  t29
# 0  0.0  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  0.0  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [2 rows x 35 columns]
# 'before concat:'
#    chemical.id     plate.id well  chemical_plate_well   conc
# 0          163  TP967-E9-P1  A10  163_TP967-E9-P1_A10  0.064
# 'after concat:'
#    chemical.id     plate.id well  chemical_plate_well   conc  t0  t1  t2  \
# 0        163.0  TP967-E9-P1  A10  163_TP967-E9-P1_A10  0.064 NaN NaN NaN
# ...

# %%
# ds = pd.Series({"Column": len_group_endpoint})
# plt.figure(figsize=(8,4))
# sns.countplot(x="Column", data=ds)
# plt.show()

# %%
display(reformatted_w_240_endpoints)
display(reformatted_w_non_240_endpoints)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#     chemical.id     plate.id well  chemical_plate_well     conc  t0  t1  t2  \
# 0         163.0  TP967-E9-P1   A1   163_TP967-E9-P1_A1  64.0000 NaN NaN NaN
# 1           NaN          NaN  NaN                  NaN      NaN NaN NaN NaN
# 0         163.0  TP967-E9-P1  A10  163_TP967-E9-P1_A10   0.0640 NaN NaN NaN
# 1           NaN          NaN  NaN                  NaN      NaN NaN NaN NaN
# 0         163.0  TP967-E9-P1  A11  163_TP967-E9-P1_A11   0.0064 NaN NaN NaN
# ..          ...          ...  ...                  ...      ...  ..  ..  ..
# 1           NaN          NaN  NaN                  NaN      NaN NaN NaN NaN
# 0         163.0  TP967-E9-P1   H8   163_TP967-E9-P1_H8   6.4000 NaN NaN NaN
# 1           NaN          NaN  NaN                  NaN      NaN NaN NaN NaN
# 0         163.0  TP967-E9-P1   H9   163_TP967-E9-P1_H9   0.6400 NaN NaN NaN
# 1           NaN          NaN  NaN                  NaN      NaN NaN NaN NaN
#
# ...

# %%
reformatted_data_filename = str(complete_input_file_path[:-9]) + "_wide_t0_t239_" + str(full_devel) + "_w_240_endpoints.csv"
reformatted_w_240_endpoints.to_csv(reformatted_data_filename,index=False)

reformatted_data_filename = str(complete_input_file_path[:-9]) + "_wide_t0_t239_" + str(full_devel) + "_w_non_240_endpoints.csv"
reformatted_w_non_240_endpoints.to_csv(reformatted_data_filename,index=False)

# %%
#display(len(np.unique(reformatted_w_240_endpoints['chemical.id'])))
display(len(np.unique(reformatted_w_non_240_endpoints['chemical.id'])))
# Out:
# 97

# %%
reformatted_w_non_240_endpoints_155 = reformatted_w_non_240_endpoints[reformatted_w_non_240_endpoints['chemical.id']==155]

display(reformatted_w_non_240_endpoints_155.head())
display(reformatted_w_non_240_endpoints_155.tail())

output_filename = str(complete_input_file_path[:-4]) + "_155_chemical_id.csv"
print ("output_filename:"+str(output_filename))
reformatted_w_non_240_endpoints_155.to_csv(output_filename, index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/kimd999/bin/miniconda3/envs/tox/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'chemical.id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
reformatted_w_non_240_endpoints_163 = reformatted_w_non_240_endpoints[reformatted_w_non_240_endpoints['chemical.id']==163]

display(reformatted_w_non_240_endpoints_163.head())
display(reformatted_w_non_240_endpoints_163.tail())

output_filename = str(complete_input_file_path[:-4]) + "_163_chemical_id.csv"
print ("output_filename:"+str(output_filename))
reformatted_w_non_240_endpoints_163.to_csv(output_filename, index=False)
# Out:
#    chemical.id     plate.id well  chemical_plate_well     conc  t0  t1  t2  \
# 0        163.0  TP967-E9-P1   A1   163_TP967-E9-P1_A1  64.0000 NaN NaN NaN
# 0        163.0  TP967-E9-P1  A10  163_TP967-E9-P1_A10   0.0640 NaN NaN NaN
# 0        163.0  TP967-E9-P1  A11  163_TP967-E9-P1_A11   0.0064 NaN NaN NaN
# 0        163.0  TP967-E9-P1  A12  163_TP967-E9-P1_A12   0.0000 NaN NaN NaN
# 0        163.0  TP967-E9-P1   A2   163_TP967-E9-P1_A2   6.4000 NaN NaN NaN
#
#      t3    t4  ...  t20  t21  t22  t23  t24  t25  t26  t27  t28  t29
# 0   0.0   0.0  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0   1.6  11.4  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0   4.7  30.7  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  68.9  40.8  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0   0.1  42.9  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 35 columns]
#    chemical.id     plate.id well chemical_plate_well     conc  t0  t1  t2  \
# ...
