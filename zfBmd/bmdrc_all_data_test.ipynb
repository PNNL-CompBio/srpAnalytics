# %%
import bmdrc
import os
import sys

# %% [markdown]
# # Define Files

# %%
chem_morpho_files = [x for x in os.listdir("/Users/degn400/Downloads/all_srp_data/cleaned_data_v2/") if "Morphology_Chemical" in x]
chem_morpho_files = [os.path.join("/Users/degn400/Downloads/all_srp_data/cleaned_data_v2/", x) for x in chem_morpho_files]

chem_behavior_files = [x for x in os.listdir("/Users/degn400/Downloads/all_srp_data/cleaned_data_v2/") if "Behavioral_Chemical" in x]
chem_behavior_files = [os.path.join("/Users/degn400/Downloads/all_srp_data/cleaned_data_v2/", x) for x in chem_behavior_files]

sample_morpho_files = [x for x in os.listdir("/Users/degn400/Downloads/all_srp_data/cleaned_data_v2/") if "Morphology_Sample" in x]
sample_morpho_files = [os.path.join("/Users/degn400/Downloads/all_srp_data/cleaned_data_v2/", x) for x in sample_morpho_files]

sample_behavior_files = [x for x in os.listdir("/Users/degn400/Downloads/all_srp_data/cleaned_data_v2/") if "Behavioral_Sample" in x]
sample_behavior_files = [os.path.join("/Users/degn400/Downloads/all_srp_data/cleaned_data_v2/", x) for x in sample_behavior_files]

# %% [markdown]
# # Chemicals

# %%
# Clocked time: 32 minutes for 12449 chemical and endpoint combinations. 3885 are modeled.
sys.argv = ["main.py", "--morpho", *chem_morpho_files, "--lpr", *chem_behavior_files, "--output_dir", "./outputs"]
exec(open("main.py").read())

# %% [markdown]
# # Samples

# %%
# Clocked time: 1 minute for 488 sample and endpoint combinations. 
sys.argv = ["main.py", "--morpho", *sample_morpho_files, "--lpr", *sample_behavior_files, "--output_dir", "./outputs", "--prefix", "sample"]
exec(open("main.py").read())
