# %%
import bmdrc
import os
import subprocess
import sys

# %% [markdown]
# # Chemical Morphology

# %%
morpho_files = [x for x in os.listdir("/Users/degn400/Downloads/all_srp_data/cleaned_data_v2/") if "Morphology_Chemical" in x]
morpho_files = [os.path.join("/Users/degn400/Downloads/all_srp_data/cleaned_data_v2/", x) for x in morpho_files]

cmd = [
    sys.executable, "./main.py",
    "--morpho", *morpho_files,
    "--output_dir", "./output"
]

subprocess.run(cmd, check=True)
# Out:
# /Users/degn400/Git_Repos/srp_continuous/New/bmdrc_testing/./main.py:175: SyntaxWarning: invalid escape sequence '\d'
#   "\d+", "", regex=True
# ...Concatenating morpho datasets
# ...Formatting morphology data
# ...Pre-Processing morphology data
# ......Pre-Processing: A do not count category was detected and those wells were changed to NA.
# ......Pre-Processing: Mortality data at 5 days was detected, and affected endpoints in wells were changed to NA.
# ......Pre-Processing: Mortality data at 24 hours was detected and affected endpoints in wells were changed to NA.
# ......Pre-Processing: Adding additional endpoints
# ...Filtering morphology data
# ...Fitting models to morphology data
# ......fitting models for 1000 ALL_BUT_MORT......fitting models for 1000 AXIS
# ......fitting models for 1000 BRN_
#
# ......fitting models for 1000 CRAN
# ......fitting models for 1000 EDEM
# ......fitting models for 1000 LTRK
# ......fitting models for 10003 ALL_BUT_MORT
# ...

# %%
morpho_files
# Out:
# ['Morphology_Chemical_20260121_FigShare263116-31021213_AlkylPAHExposure.txt',
#  'Morphology_Chemical_20210323_GitHub_Phase3.txt',
#  'Morphology_Chemical_20201216_GitHub_335ChemicalsFixed.txt',
#  'Morphology_Chemical_20260121_FigShare263116-31021453_TanguaryZF100AlkylPAH.txt',
#  'Morphology_Chemical_20231005_GitHub_Phase4Alkyl104PAH.txt',
#  'Morphology_Chemical_20181002_DropBox_5NewPAH.txt',
#  'Morphology_Chemical_20170309_DropBox_Supermix.txt',
#  'Morphology_Chemical_20151212_DropBox_125PAH.txt',
#  'Morphology_Chemical_20231005_FigShare27742668_Phase4.txt',
#  'Morphology_Chemical_20151030_DropBox_FSES1400OverlapRawData.txt',
#  'Morphology_Chemical_20161207_DropBox_138PAH.txt',
#  'Morphology_Chemical_20210426_Legacy_ZFRepull.txt',
#  'Morphology_Chemical_20251231_FigShare263116-30983269_TanguayZF6PAH.txt',
#  'Morphology_Chemical_20180522_DropBox_FSES1400.txt',
#  'Morphology_Chemical_20251231_FigShare263116-30983095_Tanguay403Antiviral.txt',
# ...
