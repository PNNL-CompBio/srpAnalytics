# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, random, time

import warnings
warnings.filterwarnings('ignore')

# %%
starting_dir = os.getcwd()
print (starting_dir)
# Out:
# /Users/kimd999/research/script_not_in_dropbox/srpAnalytics/analysis/latest/1_reformat/latest/phase_III/behavior/divide_into_two

# %% [markdown]
# ### Reformat LPR behavioral data

# %%
########## mac
complete_input_file_path= '/Users/kimd999/research/projects/toxicity/per_each_data/phase_III/input/behavior/LPR/tall/Tanguay_Phase_3_zf_LPR_data_PNNL_2021MAR23.csv'

########## constance

df_behav = pd.read_csv(complete_input_file_path, header = 0)

df_behav = df_behav.rename({'variable': 'timepoint'}, axis=1)

display(len(np.unique(df_behav['chemical.id'])))
display(df_behav.head())
# Out:
# 215
#    chemical.id      bottle.id  conc  plate.id well variable      value
# 0          234  NTP DNT 91-A1   0.0     14389  H01       t0  17.223000
# 1          234  NTP DNT 91-A1   0.0     14389  H02       t0  12.876000
# 2          234  NTP DNT 91-A1   0.0     14389  H03       t0  24.156000
# 3          234  NTP DNT 91-A1   0.0     14389  H04       t0  31.421999
# 4          234  NTP DNT 91-A1   0.0     14389  H05       t0  36.917999

# %%
# Keep only relevant columns
columns_to_keep = ['chemical.id', 'conc', 'plate.id', 'well', 'variable', 'value']
df_select = df_behav.loc[:,columns_to_keep]
df_select.head()
# Out:
#    chemical.id  conc  plate.id well variable      value
# 0          234   0.0     14389  H01       t0  17.223000
# 1          234   0.0     14389  H02       t0  12.876000
# 2          234   0.0     14389  H03       t0  24.156000
# 3          234   0.0     14389  H04       t0  31.421999
# 4          234   0.0     14389  H05       t0  36.917999

# %% [markdown]
# ### Transpose time points

# %%
start_time = time.time()

df_per_chemical_w_240_timepoints = pd.DataFrame()
df_per_chemical_w_15_timepoints = pd.DataFrame()
    
len_variable = []
len_unique_variable = []
    
full_devel = "full"
#full_devel = "devel"

chemical_id_from_here = np.unique(df_behav['chemical.id'])

if (full_devel == "devel"):
    choose_this_number = min(len(chemical_id_from_here), 1)
    randomly_chosen = random.sample(set(chemical_id_from_here), choose_this_number)
    chemical_id_from_here = []
    for i in range(len(randomly_chosen)):
        chemical_id_from_here.append(randomly_chosen[i])

total_number_of_chemicals_to_processed = len(chemical_id_from_here)
number_of_chemicals_processed = 0

for chemical_index in chemical_id_from_here:
    print("chemical_index:" + str(chemical_index))
    df_per_chemical = df_select.loc[df_behav['chemical.id'] == chemical_index,:]
    #print("len(df_per_chemical):" + str(len(df_per_chemical))) # for chemical.id=234, 69120

    if (len(np.unique(df_per_chemical['variable'])) == 240):
        df_per_chemical_w_240_timepoints = pd.concat([df_per_chemical_w_240_timepoints, df_per_chemical])
    else:
        df_per_chemical_w_15_timepoints  = pd.concat([df_per_chemical_w_15_timepoints, df_per_chemical])
    len_variable.append(len(df_per_chemical['variable']))
    len_unique_variable.append(len(np.unique(df_per_chemical['variable'])))
    
    number_of_chemicals_processed += 1
    print_this = str(number_of_chemicals_processed) + " chemicals processed out of " + str(total_number_of_chemicals_to_processed)
    print(print_this)


end_time = time.time()
time_took = str(round((end_time-start_time), 1)) + " seconds"
print ("Done, it took:"+str(time_took)) 
# took 2.5 minutes for 215 chemicals
# Out:
# chemical_index:234
# 1 chemicals processed out of 215
# chemical_index:275
# 2 chemicals processed out of 215
# chemical_index:280
# 3 chemicals processed out of 215
# chemical_index:385
# 4 chemicals processed out of 215
# chemical_index:397
# 5 chemicals processed out of 215
# chemical_index:443
# 6 chemicals processed out of 215
# chemical_index:467
# 7 chemicals processed out of 215
# chemical_index:505
# 8 chemicals processed out of 215
# chemical_index:588
# 9 chemicals processed out of 215
# chemical_index:595
# 10 chemicals processed out of 215
# chemical_index:622
# 11 chemicals processed out of 215
# chemical_index:660
# 12 chemicals processed out of 215
# chemical_index:692
# 13 chemicals processed out of 215
# chemical_index:699
# 14 chemicals processed out of 215
# chemical_index:725
# 15 chemicals processed out of 215
# chemical_index:726
# 16 chemicals processed out of 215
# chemical_index:947
# 17 chemicals processed out of 215
# chemical_index:949
# 18 chemicals processed out of 215
# chemical_index:955
# 19 chemicals processed out of 215
# chemical_index:1016
# 20 chemicals processed out of 215
# chemical_index:1017
# 21 chemicals processed out of 215
# chemical_index:1031
# 22 chemicals processed out of 215
# chemical_index:1155
# 23 chemicals processed out of 215
# chemical_index:1174
# 24 chemicals processed out of 215
# chemical_index:1175
# 25 chemicals processed out of 215
# chemical_index:1178
# 26 chemicals processed out of 215
# chemical_index:1179
# 27 chemicals processed out of 215
# chemical_index:1182
# 28 chemicals processed out of 215
# chemical_index:1189
# 29 chemicals processed out of 215
# chemical_index:1209
# 30 chemicals processed out of 215
# chemical_index:1213
# 31 chemicals processed out of 215
# chemical_index:1214
# 32 chemicals processed out of 215
# chemical_index:1215
# 33 chemicals processed out of 215
# chemical_index:1216
# 34 chemicals processed out of 215
# chemical_index:1220
# 35 chemicals processed out of 215
# chemical_index:1222
# 36 chemicals processed out of 215
# chemical_index:1241
# 37 chemicals processed out of 215
# chemical_index:1312
# 38 chemicals processed out of 215
# chemical_index:1315
# 39 chemicals processed out of 215
# chemical_index:1371
# 40 chemicals processed out of 215
# chemical_index:1430
# 41 chemicals processed out of 215
# chemical_index:1595
# 42 chemicals processed out of 215
# chemical_index:1601
# 43 chemicals processed out of 215
# chemical_index:1607
# 44 chemicals processed out of 215
# chemical_index:1610
# 45 chemicals processed out of 215
# chemical_index:1611
# 46 chemicals processed out of 215
# chemical_index:1624
# 47 chemicals processed out of 215
# chemical_index:1626
# 48 chemicals processed out of 215
# chemical_index:1642
# 49 chemicals processed out of 215
# chemical_index:1651
# 50 chemicals processed out of 215
# chemical_index:1830
# 51 chemicals processed out of 215
# chemical_index:1855
# 52 chemicals processed out of 215
# chemical_index:1898
# 53 chemicals processed out of 215
# chemical_index:1925
# 54 chemicals processed out of 215
# chemical_index:1947
# 55 chemicals processed out of 215
# chemical_index:2076
# 56 chemicals processed out of 215
# chemical_index:2090
# 57 chemicals processed out of 215
# chemical_index:2110
# 58 chemicals processed out of 215
# chemical_index:2151
# 59 chemicals processed out of 215
# chemical_index:2180
# 60 chemicals processed out of 215
# chemical_index:2192
# 61 chemicals processed out of 215
# chemical_index:2240
# 62 chemicals processed out of 215
# chemical_index:2323
# 63 chemicals processed out of 215
# chemical_index:2358
# 64 chemicals processed out of 215
# chemical_index:2585
# 65 chemicals processed out of 215
# chemical_index:2587
# 66 chemicals processed out of 215
# chemical_index:2589
# 67 chemicals processed out of 215
# chemical_index:2590
# 68 chemicals processed out of 215
# chemical_index:2594
# 69 chemicals processed out of 215
# chemical_index:2595
# 70 chemicals processed out of 215
# chemical_index:2596
# 71 chemicals processed out of 215
# chemical_index:2597
# 72 chemicals processed out of 215
# chemical_index:2598
# 73 chemicals processed out of 215
# chemical_index:2599
# 74 chemicals processed out of 215
# chemical_index:2600
# 75 chemicals processed out of 215
# chemical_index:2602
# 76 chemicals processed out of 215
# chemical_index:2635
# 77 chemicals processed out of 215
# chemical_index:2636
# 78 chemicals processed out of 215
# chemical_index:2650
# 79 chemicals processed out of 215
# chemical_index:2685
# 80 chemicals processed out of 215
# chemical_index:2686
# 81 chemicals processed out of 215
# chemical_index:2715
# 82 chemicals processed out of 215
# chemical_index:2739
# 83 chemicals processed out of 215
# chemical_index:2821
# 84 chemicals processed out of 215
# chemical_index:2973
# 85 chemicals processed out of 215
# chemical_index:2994
# 86 chemicals processed out of 215
# chemical_index:3007
# 87 chemicals processed out of 215
# chemical_index:3056
# 88 chemicals processed out of 215
# chemical_index:3133
# 89 chemicals processed out of 215
# chemical_index:3136
# 90 chemicals processed out of 215
# chemical_index:3189
# 91 chemicals processed out of 215
# chemical_index:3191
# 92 chemicals processed out of 215
# chemical_index:3766
# 93 chemicals processed out of 215
# chemical_index:3771
# 94 chemicals processed out of 215
# chemical_index:3853
# 95 chemicals processed out of 215
# chemical_index:4336
# 96 chemicals processed out of 215
# chemical_index:4337
# 97 chemicals processed out of 215
# chemical_index:4338
# 98 chemicals processed out of 215
# chemical_index:4339
# 99 chemicals processed out of 215
# chemical_index:4340
# 100 chemicals processed out of 215
# chemical_index:4341
# 101 chemicals processed out of 215
# chemical_index:4342
# 102 chemicals processed out of 215
# chemical_index:4343
# 103 chemicals processed out of 215
# chemical_index:4344
# 104 chemicals processed out of 215
# chemical_index:4345
# 105 chemicals processed out of 215
# chemical_index:4346
# 106 chemicals processed out of 215
# chemical_index:4347
# 107 chemicals processed out of 215
# chemical_index:4348
# 108 chemicals processed out of 215
# chemical_index:4349
# 109 chemicals processed out of 215
# chemical_index:4350
# 110 chemicals processed out of 215
# chemical_index:4351
# 111 chemicals processed out of 215
# chemical_index:4352
# 112 chemicals processed out of 215
# chemical_index:4353
# 113 chemicals processed out of 215
# chemical_index:4354
# 114 chemicals processed out of 215
# chemical_index:4355
# 115 chemicals processed out of 215
# chemical_index:4356
# 116 chemicals processed out of 215
# chemical_index:4357
# 117 chemicals processed out of 215
# chemical_index:4358
# 118 chemicals processed out of 215
# chemical_index:4359
# 119 chemicals processed out of 215
# chemical_index:4360
# 120 chemicals processed out of 215
# chemical_index:4361
# 121 chemicals processed out of 215
# chemical_index:4362
# 122 chemicals processed out of 215
# chemical_index:4363
# 123 chemicals processed out of 215
# chemical_index:4364
# 124 chemicals processed out of 215
# chemical_index:4365
# 125 chemicals processed out of 215
# chemical_index:4366
# 126 chemicals processed out of 215
# chemical_index:4367
# 127 chemicals processed out of 215
# chemical_index:4368
# 128 chemicals processed out of 215
# chemical_index:4369
# 129 chemicals processed out of 215
# chemical_index:4370
# 130 chemicals processed out of 215
# chemical_index:4371
# 131 chemicals processed out of 215
# chemical_index:4372
# 132 chemicals processed out of 215
# chemical_index:4373
# 133 chemicals processed out of 215
# chemical_index:4374
# 134 chemicals processed out of 215
# chemical_index:4375
# 135 chemicals processed out of 215
# chemical_index:4376
# 136 chemicals processed out of 215
# chemical_index:4377
# 137 chemicals processed out of 215
# chemical_index:4378
# 138 chemicals processed out of 215
# chemical_index:4379
# 139 chemicals processed out of 215
# chemical_index:4380
# 140 chemicals processed out of 215
# chemical_index:4381
# 141 chemicals processed out of 215
# chemical_index:4382
# 142 chemicals processed out of 215
# chemical_index:4383
# 143 chemicals processed out of 215
# chemical_index:4384
# 144 chemicals processed out of 215
# chemical_index:4385
# 145 chemicals processed out of 215
# chemical_index:4386
# 146 chemicals processed out of 215
# chemical_index:4387
# 147 chemicals processed out of 215
# chemical_index:4388
# 148 chemicals processed out of 215
# chemical_index:4390
# 149 chemicals processed out of 215
# chemical_index:4391
# 150 chemicals processed out of 215
# chemical_index:4392
# 151 chemicals processed out of 215
# chemical_index:4393
# 152 chemicals processed out of 215
# chemical_index:4394
# 153 chemicals processed out of 215
# chemical_index:4395
# 154 chemicals processed out of 215
# chemical_index:4396
# 155 chemicals processed out of 215
# chemical_index:4397
# 156 chemicals processed out of 215
# chemical_index:4398
# 157 chemicals processed out of 215
# chemical_index:4399
# 158 chemicals processed out of 215
# chemical_index:4400
# 159 chemicals processed out of 215
# chemical_index:4401
# 160 chemicals processed out of 215
# chemical_index:4402
# 161 chemicals processed out of 215
# chemical_index:4403
# 162 chemicals processed out of 215
# chemical_index:4404
# 163 chemicals processed out of 215
# chemical_index:4405
# 164 chemicals processed out of 215
# chemical_index:4406
# 165 chemicals processed out of 215
# chemical_index:4407
# 166 chemicals processed out of 215
# chemical_index:4408
# 167 chemicals processed out of 215
# chemical_index:4410
# 168 chemicals processed out of 215
# chemical_index:4411
# 169 chemicals processed out of 215
# chemical_index:4412
# 170 chemicals processed out of 215
# chemical_index:4413
# 171 chemicals processed out of 215
# chemical_index:4414
# 172 chemicals processed out of 215
# chemical_index:4415
# 173 chemicals processed out of 215
# chemical_index:4416
# 174 chemicals processed out of 215
# chemical_index:4417
# 175 chemicals processed out of 215
# chemical_index:4418
# 176 chemicals processed out of 215
# chemical_index:4419
# 177 chemicals processed out of 215
# chemical_index:4420
# 178 chemicals processed out of 215
# chemical_index:4421
# 179 chemicals processed out of 215
# chemical_index:4422
# 180 chemicals processed out of 215
# chemical_index:4423
# 181 chemicals processed out of 215
# chemical_index:4424
# 182 chemicals processed out of 215
# chemical_index:4425
# 183 chemicals processed out of 215
# chemical_index:4426
# 184 chemicals processed out of 215
# chemical_index:4427
# 185 chemicals processed out of 215
# chemical_index:4428
# 186 chemicals processed out of 215
# chemical_index:4429
# 187 chemicals processed out of 215
# chemical_index:4430
# 188 chemicals processed out of 215
# chemical_index:4431
# 189 chemicals processed out of 215
# chemical_index:4432
# 190 chemicals processed out of 215
# chemical_index:4433
# 191 chemicals processed out of 215
# chemical_index:4434
# 192 chemicals processed out of 215
# chemical_index:4435
# 193 chemicals processed out of 215
# chemical_index:4436
# 194 chemicals processed out of 215
# chemical_index:4437
# 195 chemicals processed out of 215
# chemical_index:4438
# 196 chemicals processed out of 215
# chemical_index:4439
# 197 chemicals processed out of 215
# chemical_index:4440
# 198 chemicals processed out of 215
# chemical_index:4441
# 199 chemicals processed out of 215
# chemical_index:4442
# 200 chemicals processed out of 215
# chemical_index:4443
# 201 chemicals processed out of 215
# chemical_index:4444
# 202 chemicals processed out of 215
# chemical_index:4445
# 203 chemicals processed out of 215
# chemical_index:4446
# 204 chemicals processed out of 215
# chemical_index:4447
# 205 chemicals processed out of 215
# chemical_index:4448
# 206 chemicals processed out of 215
# chemical_index:4449
# 207 chemicals processed out of 215
# chemical_index:4450
# 208 chemicals processed out of 215
# chemical_index:4451
# 209 chemicals processed out of 215
# chemical_index:4452
# 210 chemicals processed out of 215
# chemical_index:4453
# 211 chemicals processed out of 215
# chemical_index:4454
# 212 chemicals processed out of 215
# chemical_index:4455
# 213 chemicals processed out of 215
# chemical_index:4456
# 214 chemicals processed out of 215
# chemical_index:4457
# 215 chemicals processed out of 215
# Done, it took:141.3 seconds

# %%
ds = pd.Series({"Column": len_variable})
plt.figure(figsize=(8,4))
sns.countplot(x="Column", data=ds)
plt.show()


ds = pd.Series({"Column": len_unique_variable})
plt.figure(figsize=(8,4))
sns.countplot(x="Column", data=ds)
plt.show()

# %%
display(df_per_chemical_w_240_timepoints)
display(df_per_chemical_w_15_timepoints)
# Out:
#          chemical.id   conc  plate.id well variable      value
# 0                234    0.0     14389  H01       t0  17.223000
# 1                234    0.0     14389  H02       t0  12.876000
# 2                234    0.0     14389  H03       t0  24.156000
# 3                234    0.0     14389  H04       t0  31.421999
# 4                234    0.0     14389  H05       t0  36.917999
# ...              ...    ...       ...  ...      ...        ...
# 8646235         4457  100.0     22097  D01     t239   0.000000
# 8646236         4457  100.0     22097  E01     t239   0.000000
# 8646237         4457  100.0     22097  F01     t239   1.052000
# 8646238         4457  100.0     22097  G01     t239   0.000000
# 8646239         4457  100.0     22097  H01     t239   0.028000
#
# [10742880 rows x 6 columns]
# Empty DataFrame
# Columns: []
# Index: []

# %%
reformatted_data_filename = str(complete_input_file_path[:-4]) + "_" + str(full_devel) + "_w_240_timepoints.csv"
df_per_chemical_w_240_timepoints.to_csv(reformatted_data_filename,index=False)

# %%
reformatted_data_filename = str(complete_input_file_path[:-4]) + "_" + str(full_devel) + "_w_15_timepoints.csv"
df_per_chemical_w_15_timepoints.to_csv(reformatted_data_filename,index=False)

# %%
display(len(np.unique(df_per_chemical_w_240_timepoints['chemical.id'])))

#display(len(np.unique(df_per_chemical_w_15_timepoints['chemical.id'])))
# Out:
# 215
